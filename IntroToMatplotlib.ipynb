# %% [markdown]
# # <center>Introduction to matplotlib</center>

# %% [markdown]
# ![](https://matplotlib.org/_static/logo2.svg)
#
# >Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shell, the jupyter notebook, web application servers, and four graphical user interface toolkits.

# %% [markdown]
# ## Installation
#
# ```
# pip install matplotlib
# ```

# %% [markdown]
# ## Example 1
#
# Plot a simple line.

# %% [markdown]
# - Take a graph paper! (import matplotlib)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# - Specify data to plot
#
# | x | y |
# | -- |---|
# |1 | 2 |
# |2 | 4 |
# |3 | 1 |

# %%
x = [1,2,3]
y = [2,4,1]
z = [3,5,6]

# %%
# Specify X and Y axis labels
plt.xlabel('x - axis')
plt.ylabel('y - axis')
# Give title to your graph!
plt.title('My first graph!')
# Plot points on graph paper!
plt.plot(x,y)
plt.plot(y,z)
# Show the plot
plt.show()
# Close the plot
plt.close()

# %% [markdown]
# ## Example 2
#
# Plot 2 lines on same plot

# %%
# line 1 points
x1 = [1,2,3]
y1 = [2,4,1]

# line 2 points
x2 = [1,2,3]
y2 = [4,1,3]

# %%
# plotting the line 1 points 
plt.plot(x1, y1, label = "line 1")

# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2")

plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.title('Two lines on same graph!')

# show labels for different lines in a legend
plt.legend()

plt.show()

plt.close()

# %% [markdown]
# ## Example 3
#
# Customizing line plot.

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('ggplot')

# %%
x = [2,2,3,4,5,6]
y = [2,4,3,5,2,6]

# %%
plt.plot(x, y, color='green', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='blue', markersize=8)

# setting x and y axis range
plt.ylim(1,8)
plt.xlim(1,8)

plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.show()
plt.close()

# %% [markdown]
# ## Example 4
#
# Plotting bar chart.

# %%
# x-coordinates of left sides of bars 
x = [1, 2, 3, 4, 5]

# %%
# heights of bars
y = [10, 24, 36, 40, 5]

# %%
# labels for bars
tick_label = ['one', 'two', 'three', 'four', 'five']

# %%
# plotting a bar chart
plt.bar(x, y, color = ['green', ],tick_label = tick_label,
        width = 0.8, )

plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.title('My bar chart!')

plt.show()
plt.close()

# %% [markdown]
# ## Example 5
#
# Plot histogram.

# %%
ages = [2,5,70,40,30,45,50,45,43,40,44,
        60,7,13,57,18,90,77,32,21,20,40]

# %%
# setting the ranges and no. of intervals
range = (0, 100)
bins = 10

# %%
# plotting a histogram
plt.hist(ages, bins, range, color = 'green',
        histtype = 'bar', rwidth = 0.8)

plt.xlabel('age')
plt.ylabel('No. of people')

plt.title('My histogram')

plt.show()
plt.close()

# %% [markdown]
# ## Example 6
#
# Plotting scatter plot.

# %%
import numpy as np

a = np.random.random(100)
x = np.random.random(100)
r = np.random.random(100)

plt.scatter(a, r, label='Nigeria', color= "green", marker= ".")
plt.scatter(x, r, label= "Ghana", color= "red", marker= ".")
plt.legend(loc=0)
plt.title("My first scatter plot")
plt.xlabel('x_axis')
plt.ylabel('y_axis')

plt.show()
plt.close()

# %%
# plotting points as a scatter plot
plt.figure(figsize = (5,5))
plt.scatter(x, r, label= "stars", color= "blue", 
            marker= ".", s=300)

plt.xlabel('x - axis')
plt.ylabel('y- axis')

plt.title('My scatter plot!')

plt.legend(loc=5)

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-ea8f4ee442d2> in <module>
#       1 # plotting points as a scatter plot
#       2 plt.figure(figsize = (5,5))
# ----> 3 plt.scatter(x, r, label= "stars", color= "blue",
#       4             marker= ".", s=300)
#       5
#
# NameError: name 'r' is not defined

# %% [markdown]
# ## Example 7
#
# Plotting pie-chart.

# %%
# defining labels
activities = ['eat', 'sleep', 'work', 'play']

# %%
# portion covered by each label
slices = [3, 7, 8, 6]

# %%
# color for each label
colors = ['r', 'm', 'g', 'b']

# %%
#help(plt.legend())

# %%
# plotting the pie chart
plt.figure(figsize = (5,5))
plt.pie(slices, labels = activities, colors=colors, 
        startangle=90, shadow = True, explode = (0, 0, 0.5, 0),
        radius = 2.0, autopct = '%1.1f%%')

plt.legend(loc=2)

plt.show()
plt.close()

# %% [markdown]
# ## Subplots
#
# Subplots are required when we want to show two or more plots in same figure. We can do it in two ways using two slightly different methods.
#
# ## Example 8
#
# Plotting subplots using method 1

# %%
plt.figure(figsize = (8,5))
plt.subplot(1,2,1)
plt.bar(left, height, tick_label = tick_label,
        width = 0.8, color = ['red', 'blue'])

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('My bar chart 1!')

plt.subplot(1,2,2)
plt.bar(left, height, tick_label = tick_label,
        width = 0.8, color = ['green', 'yellow'])

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('My bar chart 2!')
plt.img

plt.show()

# %% [markdown]
# Figure acts as a top level container for all plot elements.

# %% [markdown]
# ![](https://indianpythonista.files.wordpress.com/2016/12/sub1.png)

# %% [markdown]
# ### Other data visualization libraries
#
# - [seaborn](https://seaborn.pydata.org/)
#
# - [plotly](https://plot.ly/)
#
# - [bokeh](https://bokeh.pydata.org/en/latest/)

# %% [markdown]
# [Notebook Source](https://github.com/nikhilkumarsingh/PythonForDataScience) from [Nikhil Kumar Singh](https://github.com/nikhilkumarsingh) on Github
